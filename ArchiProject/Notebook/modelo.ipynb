jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9726.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3733.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12698.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/7927.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14720.jpg'
# ...
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13070.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/877.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3004.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9773.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10583.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5618.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5893.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3798.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13421.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3064.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12856.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9387.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8612.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11247.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8095.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4375.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10476.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1110.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5130.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6034.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4980.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12315.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13129.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3112.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5495.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10478.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13096.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1375.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5304.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1476.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2048.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11892.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12419.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10475.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11428.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4571.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2415.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/7768.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9323.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8324.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12758.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2530.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5876.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2393.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/15364.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/7472.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1525.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11261.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1587.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5387.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10379.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10893.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/15065.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8886.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1560.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10939.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11505.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5490.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2598.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11871.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10480.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5614.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2873.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3749.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3656.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4631.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4279.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9462.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1126.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6983.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6847.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12711.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4986.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2275.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2023.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1343.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10215.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6483.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9966.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8755.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12442.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14585.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14030.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/7332.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10626.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5515.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1692.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/15404.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9081.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/513.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8239.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13284.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5788.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4688.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10435.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3438.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10257.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11051.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13031.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12343.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1608.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10344.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1905.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10687.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5445.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14099.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6655.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8297.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9406.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/15452.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8516.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5050.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10463.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/42.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1678.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3414.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11239.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6746.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12968.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13983.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14426.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8356.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11927.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5520.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12909.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14084.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13283.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8235.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12868.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8082.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2123.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13382.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6438.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/7752.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4805.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10210.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5295.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11286.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14740.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5460.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8876.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11172.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1983.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8336.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/98.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8744.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14363.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/814.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1766.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9225.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12018.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13734.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3264.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8838.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4502.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13921.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/7433.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3526.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13489.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1355.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6917.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/89.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8172.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14276.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11628.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11154.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1862.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6763.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/323.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2552.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2701.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4561.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10674.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6341.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13698.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/7929.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10669.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8350.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13298.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/15313.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6497.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8380.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10339.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9101.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12050.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11760.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4362.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3620.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14255.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6939.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13512.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12228.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9822.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12962.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3860.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2116.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6704.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12429.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1403.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/726.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/4441.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2349.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/183.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5792.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3445.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/9219.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8080.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8270.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12770.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/13757.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5032.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3039.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5735.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3835.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/311.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14024.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11029.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/11416.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2673.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6059.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12904.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/7803.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2501.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/2438.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/1199.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/14149.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/10069.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/6081.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/8204.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/7197.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/5516.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/7279.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/3599.jpg'
# b'/content/drive/MyDrive/universidad_de_chile/img_dataset/12280.jpg'

# %%
len(dataset)
# Out:
# 15473

# %%
imgurls = !ls -1 "{PATH}"

# %%
n = len(dataset)
train_n = round(n*0.80)

randurls = np.copy(imgurls)

np.random.shuffle(randurls)


#particion train / test

tr_urls  = randurls[:train_n]
ts_urls  = randurls[train_n:n]

print(len(imgurls), len(tr_urls), len(ts_urls))
# Out:
# 15473 12378 3095

# %%
def load(image_file):
  """
    Debe separar las imágenes  real de las imágenes de la etiqueta de dibujo, todas las cuales tendrán un tamaño de 256 x 256 .

    Defina una función que cargue archivos de imagen y genere dos tensores de imagen:
  """

  # Read and decode an image file to a uint8 tensor
  image = tf.io.read_file(image_file)
  image = tf.io.decode_jpeg(image)

  # Split each image tensor into two tensors:
  # - one with a real building facade image
  # - one with an architecture label image 
  w = tf.shape(image)[1]
  w = w // 2
  input_image = image[:, w:, :]
  real_image = image[:, :w, :]

  # Convert both images to float32 tensors
  input_image = tf.cast(input_image, tf.float32)
  real_image = tf.cast(real_image, tf.float32)

  return input_image, real_image

# %%
inp, re = load(PATH + '/100.jpg')
# Casting to int for matplotlib to display the images
plt.figure()
plt.imshow(inp / 255.0)
plt.figure()
plt.imshow(re / 255.0)

# %%
# The facade training set consist of 400 images
BUFFER_SIZE = 400
# The batch size of 1 produced better results for the U-Net in the original pix2pix experiment
BATCH_SIZE = 1
# Each image is 256x256 in size
IMG_WIDTH = 256
IMG_HEIGHT = 256

# %%
def resize(input_image, real_image, height, width):
  input_image = tf.image.resize(input_image, [height, width],
                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
  real_image = tf.image.resize(real_image, [height, width],
                               method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

  return input_image, real_image

# %%
def random_crop(input_image, real_image):
  stacked_image = tf.stack([input_image, real_image], axis=0)
  cropped_image = tf.image.random_crop(
      stacked_image, size=[2, IMG_HEIGHT, IMG_WIDTH, 3])

  return cropped_image[0], cropped_image[1]

# %%
# Normalizing the images to [-1, 1]
def normalize(input_image, real_image):
  input_image = (input_image / 127.5) - 1
  real_image = (real_image / 127.5) - 1

  return input_image, real_image

# %%
@tf.function()
def random_jitter(input_image, real_image):
  # Resizing to 286x286
  input_image, real_image = resize(input_image, real_image, 286, 286)

  # Random cropping back to 256x256
  input_image, real_image = random_crop(input_image, real_image)

  if tf.random.uniform(()) > 0.5:
    # Random mirroring
    input_image = tf.image.flip_left_right(input_image)
    real_image = tf.image.flip_left_right(real_image)

  return input_image, real_image

# %%
def load_image_train(image_file):
  input_image, real_image = load(image_file)
  input_image, real_image = random_jitter(input_image, real_image)
  input_image, real_image = normalize(input_image, real_image)

  return input_image, real_image

# %%
def load_image_test(image_file):
  input_image, real_image = load(image_file)
  input_image, real_image = resize(input_image, real_image,
                                   IMG_HEIGHT, IMG_WIDTH)
  input_image, real_image = normalize(input_image, real_image)

  return input_image, real_image

# %%
train_dataset = tf.data.Dataset.list_files(PATH +f'/{tr_urls}*.jpg')
train_dataset = train_dataset.map(load_image_train,
                                  num_parallel_calls=tf.data.AUTOTUNE)
train_dataset = train_dataset.shuffle(BUFFER_SIZE)
train_dataset = train_dataset.batch(BATCH_SIZE)

# %%
try:
  test_dataset = tf.data.Dataset.list_files(PATH + f'/{ts_urls}*.jpg')
except tf.errors.InvalidArgumentError:
  test_dataset = tf.data.Dataset.list_files(PATH +  f'/{ts_urls}*.jpg')
test_dataset = test_dataset.map(load_image_test)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %% [markdown]
# **Diseño de arquitectura**

# %%
OUTPUT_CHANNELS = 3

# %%
def downsample(filters, size, apply_batchnorm=True):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
      tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

  if apply_batchnorm:
    result.add(tf.keras.layers.BatchNormalization())

  result.add(tf.keras.layers.LeakyReLU())

  return result

# %%
down_model = downsample(3, 4)
down_result = down_model(tf.expand_dims(inp, 0))
print (down_result.shape)
# Out:
# (1, 128, 128, 3)

# %%
def upsample(filters, size, apply_dropout=False):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
    tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                    padding='same',
                                    kernel_initializer=initializer,
                                    use_bias=False))

  result.add(tf.keras.layers.BatchNormalization())

  if apply_dropout:
      result.add(tf.keras.layers.Dropout(0.5))

  result.add(tf.keras.layers.ReLU())

  return result

# %%
up_model = upsample(3, 4)
up_result = up_model(down_result)
print (up_result.shape)
# Out:
# (1, 256, 256, 3)

# %%
def Generator():
  inputs = tf.keras.layers.Input(shape=[256, 256, 3])

  down_stack = [
    downsample(64, 4, apply_batchnorm=False),  # (batch_size, 128, 128, 64)
    downsample(128, 4),  # (batch_size, 64, 64, 128)
    downsample(256, 4),  # (batch_size, 32, 32, 256)
    downsample(512, 4),  # (batch_size, 16, 16, 512)
    downsample(512, 4),  # (batch_size, 8, 8, 512)
    downsample(512, 4),  # (batch_size, 4, 4, 512)
    downsample(512, 4),  # (batch_size, 2, 2, 512)
    downsample(512, 4),  # (batch_size, 1, 1, 512)
  ]

  up_stack = [
    upsample(512, 4, apply_dropout=True),  # (batch_size, 2, 2, 1024)
    upsample(512, 4, apply_dropout=True),  # (batch_size, 4, 4, 1024)
    upsample(512, 4, apply_dropout=True),  # (batch_size, 8, 8, 1024)
    upsample(512, 4),  # (batch_size, 16, 16, 1024)
    upsample(256, 4),  # (batch_size, 32, 32, 512)
    upsample(128, 4),  # (batch_size, 64, 64, 256)
    upsample(64, 4),  # (batch_size, 128, 128, 128)
  ]

  initializer = tf.random_normal_initializer(0., 0.02)
  last = tf.keras.layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                         strides=2,
                                         padding='same',
                                         kernel_initializer=initializer,
                                         activation='tanh')  # (batch_size, 256, 256, 3)

  x = inputs

  # Downsampling a través del modelo
  skips = []
  for down in down_stack:
    x = down(x)
    skips.append(x)

  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    x = tf.keras.layers.Concatenate()([x, skip])

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %%
generator = Generator()
tf.keras.utils.plot_model(generator, show_shapes=True, dpi=64)

# %%
gen_output = generator(inp[tf.newaxis, ...], training=False)
plt.imshow(gen_output[0, ...])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
LAMBDA = 100

# %%
loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def generator_loss(disc_generated_output, gen_output, target):
  gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

  # Mean absolute error
  l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

  total_gen_loss = gan_loss + (LAMBDA * l1_loss)

  return total_gen_loss, gan_loss, l1_loss

# %%
def Discriminator():
  initializer = tf.random_normal_initializer(0., 0.02)

  inp = tf.keras.layers.Input(shape=[256, 256, 3], name='input_image')
  tar = tf.keras.layers.Input(shape=[256, 256, 3], name='target_image')

  x = tf.keras.layers.concatenate([inp, tar])  # (batch_size, 256, 256, channels*2)

  down1 = downsample(64, 4, False)(x)  # (batch_size, 128, 128, 64)
  down2 = downsample(128, 4)(down1)  # (batch_size, 64, 64, 128)
  down3 = downsample(256, 4)(down2)  # (batch_size, 32, 32, 256)

  zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3)  # (batch_size, 34, 34, 256)
  conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                kernel_initializer=initializer,
                                use_bias=False)(zero_pad1)  # (batch_size, 31, 31, 512)

  batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

  leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

  zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu)  # (batch_size, 33, 33, 512)

  last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                kernel_initializer=initializer)(zero_pad2)  # (batch_size, 30, 30, 1)

  return tf.keras.Model(inputs=[inp, tar], outputs=last)

# %%
discriminator = Discriminator()
tf.keras.utils.plot_model(discriminator, show_shapes=True, dpi=64)

# %%
disc_out = discriminator([inp[tf.newaxis, ...], gen_output], training=False)
plt.imshow(disc_out[0, ..., -1], vmin=-20, vmax=20, cmap='RdBu_r')
plt.colorbar()

# %%
def discriminator_loss(disc_real_output, disc_generated_output):
  real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

  generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

  total_disc_loss = real_loss + generated_loss

  return total_disc_loss

# %%
generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
checkpoint_dir = '/content/drive/MyDrive/universidad_de_chile/checkpoints/training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
def generate_images(model, test_input, tar):
  prediction = model(test_input, training=True)
  plt.figure(figsize=(15, 15))

  display_list = [test_input[0], tar[0], prediction[0]]
  title = ['Input Image', 'Ground Truth', 'Predicted Image']

  for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.title(title[i])
    # Getting the pixel values in the [0, 1] range to plot.
    plt.imshow(display_list[i] * 0.5 + 0.5)
    plt.axis('off')
  plt.show()

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
for example_input, example_target in test_dataset.take(1):
  generate_images(generator, example_input, example_target)

# %%
log_dir="logs/"

summary_writer = tf.summary.create_file_writer(
  log_dir + "fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

# %%
@tf.function
def train_step(input_image, target, step):
  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    gen_output = generator(input_image, training=True)

    disc_real_output = discriminator([input_image, target], training=True)
    disc_generated_output = discriminator([input_image, gen_output], training=True)

    gen_total_loss, gen_gan_loss, gen_l1_loss = generator_loss(disc_generated_output, gen_output, target)
    disc_loss = discriminator_loss(disc_real_output, disc_generated_output)

  generator_gradients = gen_tape.gradient(gen_total_loss,
                                          generator.trainable_variables)
  discriminator_gradients = disc_tape.gradient(disc_loss,
                                               discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(generator_gradients,
                                          generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(discriminator_gradients,
                                              discriminator.trainable_variables))

  with summary_writer.as_default():
    tf.summary.scalar('gen_total_loss', gen_total_loss, step=step//1000)
    tf.summary.scalar('gen_gan_loss', gen_gan_loss, step=step//1000)
    tf.summary.scalar('gen_l1_loss', gen_l1_loss, step=step//1000)
    tf.summary.scalar('disc_loss', disc_loss, step=step//1000)

# %%
def fit(train_ds, test_ds, steps):
  example_input, example_target = next(iter(test_ds.take(1)))
  start = time.time()

  for step, (input_image, target) in train_ds.repeat().take(steps).enumerate():
    if (step) % 1000 == 0:
      display.clear_output(wait=True)

      if step != 0:
        print(f'Time taken for 1000 steps: {time.time()-start:.2f} sec\n')

      start = time.time()

      generate_images(generator, example_input, example_target)
      print(f"Step: {step//1000}k")

    train_step(input_image, target, step)

    # Training step
    if (step+1) % 10 == 0:
      print('.', end='', flush=True)


    # Save (checkpoint) the model every 5k steps
    if (step + 1) % 5000 == 0:
      checkpoint.save(file_prefix=checkpoint_prefix)

# %%
#fit(train_dataset, test_dataset, steps=100000)

# %%
ls {checkpoint_dir}
# Out:
# assets/                      ckpt-23.data-00000-of-00001
# checkpoint                   ckpt-23.index
# ckpt-10.data-00000-of-00001  ckpt-24.data-00000-of-00001
# ckpt-10.index                ckpt-24.index
# ckpt-11.data-00000-of-00001  ckpt-25.data-00000-of-00001
# ckpt-11.index                ckpt-25.index
# ckpt-12.data-00000-of-00001  ckpt-26.data-00000-of-00001
# ckpt-12.index                ckpt-26.index
# ckpt-13.data-00000-of-00001  ckpt-27.data-00000-of-00001
# ckpt-13.index                ckpt-27.index
# ckpt-14.data-00000-of-00001  ckpt-28.data-00000-of-00001
# ckpt-14.index                ckpt-28.index
# ckpt-15.data-00000-of-00001  ckpt-2.data-00000-of-00001
# ckpt-15.index                ckpt-2.index
# ckpt-16.data-00000-of-00001  ckpt-3.data-00000-of-00001
# ckpt-16.index                ckpt-3.index
# ckpt-17.data-00000-of-00001  ckpt-4.data-00000-of-00001
# ckpt-17.index                ckpt-4.index
# ckpt-18.data-00000-of-00001  ckpt-5.data-00000-of-00001
# ckpt-18.index                ckpt-5.index
# ckpt-19.data-00000-of-00001  ckpt-6.data-00000-of-00001
# ckpt-19.index                ckpt-6.index
# ckpt-1.data-00000-of-00001   ckpt-7.data-00000-of-00001
# ckpt-1.index                 ckpt-7.index
# ckpt-20.data-00000-of-00001  ckpt-8.data-00000-of-00001
# ckpt-20.index                ckpt-8.index
# ckpt-21.data-00000-of-00001  ckpt-9.data-00000-of-00001
# ckpt-21.index                ckpt-9.index
# ckpt-22.data-00000-of-00001  saved_model.pb
# ckpt-22.index                variables/

# %%
# Restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
# Run the trained model on a few examples from the test set
for inp, tar in test_dataset.take(50):
  generate_images(generator, inp, tar)

# %%
generator.save('/content/drive/MyDrive/universidad_de_chile/generator.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
